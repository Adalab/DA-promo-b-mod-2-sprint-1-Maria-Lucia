# %%
import pandas as pd

# %%
# Ejercicio

# En este ejercicio de pair programming pondremos en práctica como cargar distintos tipos de archivos en Python usando Pandas.

# Id cargando todos los ficheros en vuestro jupyter

# %%
archivo_csv = pd.read_csv("./ficheros_pandas/quejas.csv", encoding = 'ISO-8859-1', sep = ";")
archivo_csv
# Out:
#             tipo                   estado canal_entrada        fecha_entrada  \
# 0          Queja  Recepcionada por Unidad      INTERNET  2022-01-28 00:00:00
# 1          Queja  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
# 2          Queja  Recepcionada por Unidad      INTERNET  2022-03-23 00:00:00
# 3          Queja  Recepcionada por Unidad      INTERNET  2022-01-24 00:00:00
# 4          Queja  Recepcionada por Unidad      INTERNET  2022-03-29 00:00:00
# ...          ...                      ...           ...                  ...
# 4494  Sugerencia                Cancelada      INTERNET  2022-01-02 00:00:00
# 4495  Sugerencia       Rechazada por SGAC      INTERNET  2022-03-08 00:00:00
# 4496       Queja       Rechazada por SGAC      INTERNET  2022-01-24 00:00:00
# 4497       Queja       Rechazada por SGAC      INTERNET  2022-01-21 00:00:00
# 4498       Queja       Rechazada por SGAC      INTERNET  2022-01-21 00:00:00
#
# ...

# %%
archivo_json = pd.read_json("./ficheros_pandas/quejas.json")
archivo_json
# Out:
#                                                    data
# 0     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 1     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 2     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 3     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 4     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# ...                                                 ...
# 4442  {'unidad_descripcion': '', 'tipo': 'Sugerencia...
# 4443  {'unidad_descripcion': '', 'tipo': 'Sugerencia...
# 4444  {'unidad_descripcion': '', 'tipo': 'Queja', 'e...
# 4445  {'unidad_descripcion': '', 'tipo': 'Queja', 'e...
# 4446  {'unidad_descripcion': '', 'tipo': 'Queja', 'e...
#
# [4447 rows x 1 columns]

# %%
archivo_xlsx = pd.read_excel("./ficheros_pandas/quejas2.xlsx")
archivo_xlsx
# Out:
#           DESCRIPCION_TEMA                                DESCRIPCION_SUBTEMA
# 0    ATENCIÓN AL CIUDADANO                         ADMINISTRACIÓN ELECTRÓNICA
# 1    ATENCIÓN AL CIUDADANO                                    FUNCIÓN PÚBLICA
# 2    ATENCIÓN AL CIUDADANO  OFICINAS DE ATENCIÓN AL CIUDADANO DE LA COMUNI...
# 3    ATENCIÓN AL CIUDADANO     OFICINAS DE REGISTRO DE LA COMUNIDAD DE MADRID
# 4    ATENCIÓN AL CIUDADANO                                              OTROS
# ..                     ...                                                ...
# 179               VIVIENDA                                       PLAN ALQUILA
# 180               VIVIENDA                             PLAN DE VIVIENDA JOVEN
# 181               VIVIENDA                                 PORTAL DE VIVIENDA
# 182               VIVIENDA                   PUNTOS DE INFORMACIÓN Y REGISTRO
# 183               VIVIENDA                                VIVIENDAS DEL IVIMA
#
# [184 rows x 2 columns]

# %%
archivo_pickle = pd.read_pickle("./ficheros_pandas/algas.pickle")
archivo_pickle
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4t/jwz4fg1j3ps9fv1187b_jzr40000gn/T/ipykernel_2176/3881894331.py in <module>
# ----> 1 archivo_pickle = pd.read_pickle("./ficheros_pandas/algas.pickle")
#       2 archivo_pickle
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     220                 #  "No module named 'pandas.core.sparse.series'"
#     221                 #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 222                 return pc.load(handles.handle, encoding=None)
#     223         except UnicodeDecodeError:
#     224             # e.g. can occur for files written in py27; see GH#28645 and GH#31988
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, is_verbose)
# ...

# %%
# Para poner el práctica el read_clipboard elegir alguna tabla que os podaís encontrar en google y usad dicho método para traer los datos al jupyter notebook. 
# Una vez que los hayáis cargado, guardad esos datos en los siguientes formatos:

# %%
rayos = pd.read_clipboard()
rayos
# Out:
#    00:00  -  02:00  0  0.1
# 0  02:00  -  04:00  0    0
# 1  04:00  -  06:00  0    0

# %%
rayos.to_csv("./ficheros_pandas/rayos/rayos.csv")

# %%
rayos.to_excel("./ficheros_pandas/rayos/rayos.xlsx")

# %%
rayos.to_json("./ficheros_pandas/rayos/rayos.json")

# %%
rayos.to_pickle("./ficheros_pandas/rayos/rayos.pickle")

# %%
#Probamos aquí a abrir un archivo pickle porque algas.pickle nos da error

rayos_pickle = pd.read_pickle("./ficheros_pandas/rayos/rayos.pickle")
rayos_pickle
# Out:
#    00:00  -  02:00  0  0.1
# 0  02:00  -  04:00  0    0
# 1  04:00  -  06:00  0    0

# %%
#Prueba de otro clipboard

candieira = pd.read_clipboard(sep = "\t")
candieira
# Out:
#     Código validación                   Data Código parámetro  \
# 0                   1  2022-08-22 00:10:00.0     BCN_AVG_1.5m
# 1                   1  2022-08-22 00:10:00.0      PP_SUM_1.5m
# 2                   1  2022-08-22 00:10:00.0         DV_SD_2m
# 3                   1  2022-08-22 00:10:00.0         VV_SD_2m
# 4                   1  2022-08-22 00:10:00.0  DV_CONDICION_2m
# 5                   1  2022-08-22 00:10:00.0        DV_AVG_2m
# 6                   1  2022-08-22 00:10:00.0        HF_SUM_2m
# 7                   1  2022-08-22 00:10:00.0  HS_CV_AVG_-0.2m
# 8                   1  2022-08-22 00:10:00.0      HR_AVG_1.5m
# 9                   1  2022-08-22 00:10:00.0      PR_AVG_1.5m
# 10                  1  2022-08-22 00:10:00.0    PRED_AVG_1.5m
# 11                  1  2022-08-22 00:10:00.0      VV_RACHA_2m
# 12                  1  2022-08-22 00:10:00.0      TO_AVG_1.5m
# 13                  1  2022-08-22 00:10:00.0     TS_AVG_-0.1m
#
# ...
