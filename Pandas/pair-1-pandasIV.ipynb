# %%
import pandas as pd
import numpy as np

# %%
# cargar csv anterior de pandasIII

tiburones = pd.read_csv("./ficheros_pandas/tiburones.csv")

# %%
tamaño_con_nulos = tiburones.shape
tamaño_con_nulos
# Out:
# (6114, 15)

# %%
# eliminar todos los nulos del DataFrame, utilizando el siguiente código dado: df.dropna(inplace = True)

tiburones.dropna(inplace = True)

# %%
tamaño_sin_nulos = tiburones.shape
tamaño_sin_nulos
# Out:
# (1502, 15)

# %%
# Ejercicio 1:
# ¿Cuántas filas se han eliminado con esta línea de código?
filas_borradas = tamaño_con_nulos[0] - tamaño_sin_nulos[0]
filas_borradas
# Out:
# 4612

# %%
# Ejercicio 2:
# ¿Cuál es el número de ataques que se han producido en Estados Unidos?


tiburones[tiburones["country"] == "USA"].shape[0] #filtramos por usa, y contamos el número de filas.
# Out:
# 719

# %%
# Ejercicio 3:
# ¿Y en España?

tiburones["country"].unique() #usamos esto para ver como escriben España

tiburones[tiburones["country"] == "SPAIN"].shape[0]
# Out:
# 5

# %%
# 3.1 ¿En qué regiones se han producido los ataques?

casos_en_España = tiburones[tiburones["country"] == "SPAIN"]

# %%
# 3.2 ¿Cuántos ataques se han producido en cada área?

áreas_de_ataques = casos_en_España["area"].unique()
casos_por_area2 = casos_en_España["area"].value_counts()
casos_por_area2
# Out:
# Castellón              1
# Alicante Province      1
# Alicante               1
# Grand Canary Island    1
# Costa Blanca           1
# Name: area, dtype: int64

# %%
casos_en_España.shape[0]
# Out:
# 5

# %%
# Ejercicio 4:
# Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
# NOTA: Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.

# %%
# metodo usando dos condiciones de filtrado

usa_aus_1 = tiburones[(tiburones["country"] == "USA") | (tiburones["country"] == "AUSTRALIA")]
usa_aus_1
# Out:
#       Unnamed: 0  unnamed:_0   case_number    year        type    country  \
# 0              0           0    2018.06.25  2018.0     Boating        USA
# 8              8           8  2018.05.26.b  2018.0  Unprovoked        USA
# 10            10          10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 21            21          21  2018.04.25.a  2018.0  Unprovoked  AUSTRALIA
# 35            35          35    2018.03.31  2018.0  Unprovoked        USA
# ...          ...         ...           ...     ...         ...        ...
# 5359        5359        5375    1912.01.26  1912.0  Unprovoked  AUSTRALIA
# 5481        5481        5498    1905.03.26  1905.0  Unprovoked  AUSTRALIA
# 5631        5631        5648    1894.11.28  1894.0  Unprovoked  AUSTRALIA
# 5667        5667        5684    1892.03.02  1892.0    Provoked  AUSTRALIA
# 5797        5797        5814    1880.11.25  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 0            California                     Oceanside, San Diego County
# 8               Florida                    Cocoa Beach, Brevard  County
# 10           Queensland                                 Cairns Aquarium
# 21    Western Australia                         Surfers Point, Prevelly
# 35               Hawaii                                     Kukio Beach
# ...                 ...                                             ...
# 5359    New South Wales  Fig Tree Bridge, Lane Cove River, near Sydney
# 5481    New South Wales                                         Lismore
# 5631    New South Wales                                      Newcastle
# 5667    New South Wales                                  Lake Macquarie
# 5797         Queensland                    Petrie Bight, Brisbane River
#
#                      activity                 name sex_ age       time  \
# 0                    Paddling          Julie Wolfe    F  57      18h00
# 8                     Walking            Cody High    M  15      17h00
# 10             Feeding sharks                 male    M  32    Morning
# 21                    Surfing            Rob Bruce    M  60      09h30
# 35    Stand-Up Paddleboarding                 male    M  25      09h30
# ...                       ...                  ...  ...  ..        ...
# 5359                 Swimming  James Edward Morgan    M  21      15h00
# 5481                  Bathing         Richard Owen    M  40    Morning
# 5631                  Bathing       Horace Hewison    M  19    Morning
# 5667                  Fishing     Christopher Wang    M  21      Night
# 5797                 Swimming         Alexey Drury    M  12  Afternoon
#
#                                                species_  \
# 0                                           White shark
# 8                                        Bull shark, 6'
# 10                                      Grey reef shark
# 21                                            3 m shark
# 35                                     Tiger shark, 12'
# ...                                                 ...
# 5359  2.8 m [9'3"] whaler shark captured 3 days late...
# 5481                                           5' shark
# 5631                                   10' to 12' shark
# 5667                                          12' shark
# 5797                                         Bull shark
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...
# 35    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5359  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5481  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5631  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5667  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5797  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [1043 rows x 15 columns]

# %%
# metodo isin

usa_aus_2 = tiburones[tiburones["country"].isin(["USA", "AUSTRALIA"] )]
usa_aus_2
# Out:
#       Unnamed: 0  unnamed:_0   case_number    year        type    country  \
# 0              0           0    2018.06.25  2018.0     Boating        USA
# 8              8           8  2018.05.26.b  2018.0  Unprovoked        USA
# 10            10          10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 21            21          21  2018.04.25.a  2018.0  Unprovoked  AUSTRALIA
# 35            35          35    2018.03.31  2018.0  Unprovoked        USA
# ...          ...         ...           ...     ...         ...        ...
# 5359        5359        5375    1912.01.26  1912.0  Unprovoked  AUSTRALIA
# 5481        5481        5498    1905.03.26  1905.0  Unprovoked  AUSTRALIA
# 5631        5631        5648    1894.11.28  1894.0  Unprovoked  AUSTRALIA
# 5667        5667        5684    1892.03.02  1892.0    Provoked  AUSTRALIA
# 5797        5797        5814    1880.11.25  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 0            California                     Oceanside, San Diego County
# 8               Florida                    Cocoa Beach, Brevard  County
# 10           Queensland                                 Cairns Aquarium
# 21    Western Australia                         Surfers Point, Prevelly
# 35               Hawaii                                     Kukio Beach
# ...                 ...                                             ...
# 5359    New South Wales  Fig Tree Bridge, Lane Cove River, near Sydney
# 5481    New South Wales                                         Lismore
# 5631    New South Wales                                      Newcastle
# 5667    New South Wales                                  Lake Macquarie
# 5797         Queensland                    Petrie Bight, Brisbane River
#
#                      activity                 name sex_ age       time  \
# 0                    Paddling          Julie Wolfe    F  57      18h00
# 8                     Walking            Cody High    M  15      17h00
# 10             Feeding sharks                 male    M  32    Morning
# 21                    Surfing            Rob Bruce    M  60      09h30
# 35    Stand-Up Paddleboarding                 male    M  25      09h30
# ...                       ...                  ...  ...  ..        ...
# 5359                 Swimming  James Edward Morgan    M  21      15h00
# 5481                  Bathing         Richard Owen    M  40    Morning
# 5631                  Bathing       Horace Hewison    M  19    Morning
# 5667                  Fishing     Christopher Wang    M  21      Night
# 5797                 Swimming         Alexey Drury    M  12  Afternoon
#
#                                                species_  \
# 0                                           White shark
# 8                                        Bull shark, 6'
# 10                                      Grey reef shark
# 21                                            3 m shark
# 35                                     Tiger shark, 12'
# ...                                                 ...
# 5359  2.8 m [9'3"] whaler shark captured 3 days late...
# 5481                                           5' shark
# 5631                                   10' to 12' shark
# 5667                                          12' shark
# 5797                                         Bull shark
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...
# 35    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5359  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5481  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5631  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5667  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5797  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [1043 rows x 15 columns]

# %%
usa_aus_1 == usa_aus_2
# Out:
#       Unnamed: 0  unnamed:_0  case_number  year  type  country  area  \
# 0           True        True         True  True  True     True  True
# 8           True        True         True  True  True     True  True
# 10          True        True         True  True  True     True  True
# 21          True        True         True  True  True     True  True
# 35          True        True         True  True  True     True  True
# ...          ...         ...          ...   ...   ...      ...   ...
# 5359        True        True         True  True  True     True  True
# 5481        True        True         True  True  True     True  True
# 5631        True        True         True  True  True     True  True
# 5667        True        True         True  True  True     True  True
# 5797        True        True         True  True  True     True  True
#
#       location  activity  name  sex_   age  time  species_  href
# 0         True      True  True  True  True  True      True  True
# 8         True      True  True  True  True  True      True  True
# 10        True      True  True  True  True  True      True  True
# 21        True      True  True  True  True  True      True  True
# 35        True      True  True  True  True  True      True  True
# ...        ...       ...   ...   ...   ...   ...       ...   ...
# 5359      True      True  True  True  True  True      True  True
# 5481      True      True  True  True  True  True      True  True
# 5631      True      True  True  True  True  True      True  True
# 5667      True      True  True  True  True  True      True  True
# 5797      True      True  True  True  True  True      True  True
#
# [1043 rows x 15 columns]

# %%
# 4.1 ¿Cuántos ataques se han producido en cada país?

print(usa_aus_1[usa_aus_1["country"] == "USA"].shape[0])
print(usa_aus_1[usa_aus_1["country"] == "AUSTRALIA"].shape[0])
# Out:
# 719
# 324

# %%
# 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

usa_aus_1[(usa_aus_1["country"] == "AUSTRALIA") & (usa_aus_1["activity"] == "Paddling")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, unnamed:_0, case_number, year, type, country, area, location, activity, name, sex_, age, time, species_, href]
# Index: []

# %%
# 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?

# metodo usando dos condiciones de filtrado

usa_aus_1[(usa_aus_1["country"] == "AUSTRALIA") & (usa_aus_1["year"] < 2000.0)].shape[0]
# Out:
# 151

# %%
# metodo is in

usa_aus_2[usa_aus_2["country"].isin(["AUSTRALIA"])][usa_aus_2[usa_aus_2["country"].isin(["AUSTRALIA"])]["year"]<2000.0].shape[0]
# Out:
# 151

# %%
# 4.4 ¿Y después del 2000?

# metodo usando dos condiciones de filtrado

usa_aus_1[(usa_aus_1["country"] == "AUSTRALIA") & (usa_aus_1["year"] > 2000.0)].shape[0]
# Out:
# 167

# %%
# Ejercicios 5:
# Extraed unicamente los ataques a mujeres.

ataques_mujeres = tiburones[tiburones["sex_"] == "F"]
ataques_mujeres
# Out:
#       Unnamed: 0  unnamed:_0   case_number    year        type       country  \
# 0              0           0    2018.06.25  2018.0     Boating           USA
# 40            40          40    2018.02.23  2018.0  Unprovoked     AUSTRALIA
# 53            53          53    2017.12.31  2017.0  Unprovoked           USA
# 71            71          71    2017.10.22  2017.0  Unprovoked     AUSTRALIA
# 75            75          75    2017.10.05  2017.0  Unprovoked           USA
# ...          ...         ...           ...     ...         ...           ...
# 4151        4151        4163    1958.04.05  1958.0  Unprovoked  SOUTH AFRICA
# 4170        4170        4182    1957.12.30  1957.0  Unprovoked  SOUTH AFRICA
# 4678        4678        4690    1942.12.26  1942.0  Unprovoked     AUSTRALIA
# 4706        4706        4718    1942.01.04  1942.0  Unprovoked     AUSTRALIA
# 4913        4913        4925  1934.12.31.b  1934.0  Unprovoked     AUSTRALIA
#
#                  area                                           location  \
# 0          California                        Oceanside, San Diego County
# 40    New South Wales                 Little Congwong Beach, La Perouse
# 53             Hawaii                               Hultin's Beach, Oahu
# 71    South Australia                                        Normanville
# 75             Hawaii                         Kamaole Beach Park, Maui
# ...               ...                                                ...
# 4151    KwaZulu-Natal                                             Uvongo
# 4170    KwaZulu-Natal                                            Margate
# 4678  New South Wales  Bantry Bay, near Ironstone Point, Middle Harbo...
# 4706  New South Wales                    Egg Rock, Middle Harbor, Sydney
# 4913  New South Wales                         Georges River at Kentucky
#
#                          activity                   name sex_ age  \
# 0                        Paddling            Julie Wolfe    F  57
# 40                       Swimming         Anna Shurapey     F  55
# 53                        Surfing       Marjorie Mariano    F  54
# 71             Kayaking / Fishing         Sarah Williams    F  15
# 75                     Snorkeling                 female    F  40
# ...                           ...                    ...  ...  ..
# 4151  Paddling in knee-deep water       Fay Jones Bester    F  28
# 4170                     Standing         Julia Painting    F  14
# 4678     Dog paddling or standing  Denise Rosemary Burch    F  15
# 4706                     Swimming          Zita Steadman    F  28
# 4913                    Splashing           Beryl Morrin    F  13
#
#              time                             species_  \
# 0           18h00                          White shark
# 40    19h00, Dusk  Juvenile white shark,  2.7 to 3.2 m
# 53          18h00                          Tiger shark
# 71      Afternoon                   White shark, 4.5 m
# 75          12h30                             8' shark
# ...           ...                                  ...
# 4151        11h10                      3 m [10'] shark
# 4170        12h40                     1.8 m [6'] shark
# 4678        10h50                           Bull shark
# 4706        15h00               Bull shark, 4 m [13']
# 4913        20h15             Tiger shark, 1.5 m [5']
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 40    http://sharkattackfile.net/spreadsheets/pdf_di...
# 53    http://sharkattackfile.net/spreadsheets/pdf_di...
# 71    http://sharkattackfile.net/spreadsheets/pdf_di...
# 75    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 4151  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4170  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4678  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4706  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4913  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [207 rows x 15 columns]

# %%
# Ejercicio 6:
# ¿Cuántas mujeres fueron atacadas en España?

mujeres_en_españa = tiburones[(tiburones["sex_"] == "F") & (tiburones["country"] == "SPAIN")]
mujeres_en_españa.shape[0]
# Out:
# 1

# %%
# Ejercicio 7:
# Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

tiburones[tiburones["year"].isin([2000, 1997, 2006])]
# Out:
#       Unnamed: 0  unnamed:_0   case_number    year        type       country  \
# 1407        1407        1412    2006.12.18  2006.0  Unprovoked     AUSTRALIA
# 1408        1408        1413    2006.12.11  2006.0  Unprovoked   NEW ZEALAND
# 1409        1409        1414    2006.12.10  2006.0  Unprovoked           USA
# 1410        1410        1415    2006.12.06  2006.0    Provoked  SOUTH AFRICA
# 1411        1411        1416    2006.12.02  2006.0  Unprovoked     AUSTRALIA
# ...          ...         ...           ...     ...         ...           ...
# 2246        2246        2253  1997.05.31.b  1997.0  Unprovoked           USA
# 2247        2247        2254  1997.05.31.a  1997.0  Unprovoked           USA
# 2252        2252        2259  1997.02.28.a  1997.0  Unprovoked     AUSTRALIA
# 2256        2256        2263    1997.01.25  1997.0  Unprovoked     AUSTRALIA
# 2257        2257        2264    1997.01.20  1997.0  Unprovoked     AUSTRALIA
#
#                    area                              location       activity  \
# 1407           Victoria                Winki Pop, Bells Beach        Surfing
# 1408       North Island                      Raglan, Manu Bay        Surfing
# 1409         California            Dillon Beach, Marin County        Surfing
# 1410      KwaZulu-Natal                            Cape Vidal        Fishing
# 1411  Western Australia                         Wharton Beach  Body boarding
# ...                 ...                                   ...            ...
# 2246            Florida         Flagler Beach, Flagler County        Surfing
# 2247            Florida         Flagler Beach, Flagler County        Surfing
# 2252         Queensland                    Whitsunday Passage   Scuba diving
# 2256         Queensland  Whitehaven Beach, Whitsundays Island     Snorkeling
# 2257  Western Australia                             Geraldton    Windsurfing
#
#                       name sex_  age           time  \
# 1407          Peter Galvin    M   25          20h00
# 1408  Elliot Paerata-Reid     M   10          11h00
# 1409          Royce Fraley    M   43          11h50
# 1410      Peter Willoughby    M   25      "Evening"
# 1411       Zac Golebiowski    M   15          07h30
# ...                    ...  ...  ...            ...
# 2246         Robert Fuller    M   34          11h00
# 2247        Johnny  Bowden    M   12          11h00
# 2252          Gerald Rauch    M   30         Midday
# 2256         Derek Burrows    M   27  11h00 / 11h30
# 2257     Werner Schonhofer    M   41          18h00
#
#                              species_  \
# 1407                 2.5 to 3 m shark
# 1408                   2 to 3 m shark
# 1409         White shark, 12' to 15'
# 1410        Raggedtooth shark, 150-kg
# 1411                 White shark, 5m
# ...                               ...
# 2246            Possibly a sand shark
# 2247            Possibly a sand shark
# 2252           Tiger shark, 2m to 3m
# 2256  1.8 m to 2.1 m [6' to 7'] shark
# 2257       Tiger shark, 4.5 m [14'9"]
#
#                                                    href
# 1407  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1408  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1409  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1410  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1411  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 2246  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2247  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2252  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2256  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2257  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [92 rows x 15 columns]

# %%
# Ejercicio 8:
# Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil. 
# En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). 
# Usad el método str.contains() para resolver este ejercicio.

tiburones["species_"].unique()
patron1 = "([w|W]hite)"

ataques_blanco = tiburones[tiburones["species_"].str.contains(patron1, regex=True)]
ataques_blanco
# Out:
# /tmp/ipykernel_10839/1051787300.py:9: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   ataques_blanco = tiburones[tiburones["species_"].str.contains(patron1, regex=True)]
#       Unnamed: 0  unnamed:_0 case_number    year        type       country  \
# 0              0           0  2018.06.25  2018.0     Boating           USA
# 24            24          24  2018.04.22  2018.0  Unprovoked  SOUTH AFRICA
# 34            34          34  2018.04.03  2018.0  Unprovoked  SOUTH AFRICA
# 40            40          40  2018.02.23  2018.0  Unprovoked     AUSTRALIA
# 60            60          60  2017.11.24  2017.0  Unprovoked           USA
# ...          ...         ...         ...     ...         ...           ...
# 5212        5212        5225  1922.05.06  1922.0  Unprovoked  SOUTH AFRICA
# 5216        5216        5229  1922.03.02  1922.0  Unprovoked     AUSTRALIA
# 5218        5218        5231  1922.02.04  1922.0  Unprovoked     AUSTRALIA
# 5297        5297        5311  1916.07.01  1916.0  Unprovoked           USA
# 5528        5528        5545  1901.07.30  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                            location  \
# 0                California         Oceanside, San Diego County
# 24    Western Cape Province      Robberg Beach, Plettenberg Bay
# 34    Eastern Cape Province                     St. Francis Bay
# 40          New South Wales  Little Congwong Beach, La Perouse
# 60               California    Stillwater Cove, Monterey County
# ...                     ...                                 ...
# 5212  Western Cape Province             Simons Town, False Bay
# 5216        New South Wales                              Coogee
# 5218        New South Wales                             Coogee
# 5297             New Jersey           Beach Haven, Ocean County
# 5528  Western Cape Province                      Windmill Beach
#
#                         activity  \
# 0                       Paddling
# 24                 Paddle-skiing
# 34                       Surfing
# 40                      Swimming
# 60                  Spearfishing
# ...                          ...
# 5212                    Swimming
# 5216  Bathing in knee-deep water
# 5218                    Swimming
# 5297                    Swimming
# 5528                    Swimming
#
#                                                   name sex_ age         time  \
# 0                                          Julie Wolfe    F  57        18h00
# 24                                                male    M  33        09h40
# 34                                        Ross Spowart    M  19        15h00
# 40                                      Anna Shurapey     F  55  19h00, Dusk
# 60                                      Grigor Azatian    M  25        13h45
# ...                                                ...  ...  ..          ...
# 5212                                   Edward G. Pells    M  18         A.M.
# 5216                                     Mervyn Gannon    M  21        11h00
# 5218                                   Milton Coughlan    M  18        15h30
# 5297                                Charles E. Vansant    M  24        17h00
# 5528  John Hendrick Adrian Chandler, a prisoner of war    M  29        14h15
#
#                                                species_  \
# 0                                           White shark
# 24                                   White shark, 2.5 m
# 34                                          White shark
# 40                  Juvenile white shark,  2.7 to 3.2 m
# 60                                   White shark, 4.6 m
# ...                                                 ...
# 5212  White shark, 12', identity confirmed by tooth ...
# 5216                           White shark, 2.4 m [8']
# 5218                                        White shark
# 5297      Thought to involve a 2.6 m [8.5'] white shark
# 5528                                        White shark
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 24    http://sharkattackfile.net/spreadsheets/pdf_di...
# 34    http://sharkattackfile.net/spreadsheets/pdf_di...
# 40    http://sharkattackfile.net/spreadsheets/pdf_di...
# 60    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5212  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5216  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5218  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5528  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [379 rows x 15 columns]

# %%
# Ejercicio 9:
# Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

patron2 = "([w|W]hite)|([T|t]iger)"

ataques_blanco_tigre = tiburones[tiburones["species_"].str.contains(patron2, regex=True)]
ataques_blanco_tigre.sample(10)
# Out:
# /tmp/ipykernel_10839/1560155179.py:6: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   ataques_blanco_tigre = tiburones[tiburones["species_"].str.contains(patron2, regex=True)]
#       Unnamed: 0  unnamed:_0   case_number    year        type       country  \
# 1889        1889        1896  2001.09.30.b  2001.0  Unprovoked        MEXICO
# 1415        1415        1420    2006.10.31  2006.0  Unprovoked           USA
# 4754        4754        4766    1940.03.31  1940.0  Unprovoked  SOUTH AFRICA
# 18            18          18  2018.04.28.b  2018.0  Unprovoked    COSTA RICA
# 2148        2148        2155  1998.11.02.a  1998.0  Unprovoked        BRAZIL
# 3983        3983        3995    1960.04.24  1960.0  Unprovoked           USA
# 1218        1218        1223  2008.07.30.R  2008.0  Unprovoked     AUSTRALIA
# 1616        1616        1623    2004.11.15  2004.0  Unprovoked  SOUTH AFRICA
# 2271        2271        2278  1996.10.03.a  1996.0  Unprovoked           USA
# 4292        4292        4304    1955.02.05  1955.0  Unprovoked     AUSTRALIA
#
#                        area                                 location  \
# 1889               Guerrero                                   Ixtapa
# 1415                 Oregon       Siletz River mouth, Lincoln County
# 4754          KwaZulu-Natal   Danger Pool, Winkelspruit, South Coast
# 18             Cocos Island                                Manuelita
# 2148             Pernambuco                 Boa Viagem Beach, Recife
# 3983             California              Tomales Point, Marin County
# 1218               Victoria                              Levys Beach
# 1616  Western Cape Province                     Fish Hoek, False Bay
# 2271             California  North Salmon Creek Beach, Sonoma County
# 4292        New South Wales     Sugarloaf Bay, Middle Harbor, Sydney
#
#                                      activity  \
# 1889                             Body surfing
# 1415                                  Surfing
# 4754                           Treading water
# 18                               Scuba diving
# 2148                                  Surfing
# 3983  Skindiving for abalone (but at surface)
# 1218                                  Surfing
# 1616                                 Swimming
# 2271                                  Surfing
# 4292                                 Swimming
#
#                                       name sex_ age                 time  \
# 1889                         Brian Lavelle    M  26         Late morning
# 1415                            Tony Perez    M  22  Just before sundown
# 4754                              Joe Lees    M  25                11h00
# 18                                    male    M  30                10h40
# 2148  Claudio Roberto Florencio de Freitas    M  22       Late afternoon
# 3983                      Frank I. Gilbert    M  48                14h00
# 1218                           Aaron Seare    M  31                10h30
# 1616                             Tyna Webb    F  77                07h00
# 2271                         Kennon Cahill    M  31                07h19
# 4292             Bruno Aloysius Rautenberg    M  25                14h35
#
#                                                species_  \
# 1889                            Tiger shark, 1.8 m [6']
# 1415                                  White shark, 16'
# 4754  White shark, species identity confirmed by too...
# 18                                          Tiger shark
# 2148                    Though to involve a white shark
# 3983                          White shark, 4.9 m [16']
# 1218                     8' white shark or 7-gill shark
# 1616                              6 m [20'] white shark
# 2271                            5 m [16.5'] white shark
# 4292             3.6 m  white shark  (or bronze whaler)
#
#                                                    href
# 1889  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1415  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4754  http://sharkattackfile.net/spreadsheets/pdf_di...
# 18    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2148  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3983  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1218  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1616  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2271  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4292  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# Ejercicio 10:
# Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. 
# Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.
tiburones["siglo"] =np.where(tiburones["year"] < 2000, "sigloXX", "sigloXXI")
tiburones
# Out:
#       Unnamed: 0  unnamed:_0   case_number    year        type       country  \
# 0              0           0    2018.06.25  2018.0     Boating           USA
# 6              6           6  2018.06.03.a  2018.0  Unprovoked        BRAZIL
# 8              8           8  2018.05.26.b  2018.0  Unprovoked           USA
# 10            10          10    2018.05.24  2018.0    Provoked     AUSTRALIA
# 13            13          13  2018.05.13.a  2018.0     Invalid       ENGLAND
# ...          ...         ...           ...     ...         ...           ...
# 5528        5528        5545    1901.07.30  1901.0  Unprovoked  SOUTH AFRICA
# 5631        5631        5648    1894.11.28  1894.0  Unprovoked     AUSTRALIA
# 5667        5667        5684    1892.03.02  1892.0    Provoked     AUSTRALIA
# 5797        5797        5814    1880.11.25  1880.0  Unprovoked     AUSTRALIA
# 5905        5905        5922    1868.05.13  1868.0  Unprovoked         INDIA
#
#                        area                      location        activity  \
# 0                California   Oceanside, San Diego County        Paddling
# 6                Pernambuco         Piedade Beach, Recife        Swimming
# 8                   Florida  Cocoa Beach, Brevard  County         Walking
# 10               Queensland               Cairns Aquarium  Feeding sharks
# 13                 Cornwall                Off Land's End         Fishing
# ...                     ...                           ...             ...
# 5528  Western Cape Province                Windmill Beach        Swimming
# 5631        New South Wales                    Newcastle          Bathing
# 5667        New South Wales                Lake Macquarie         Fishing
# 5797             Queensland  Petrie Bight, Brisbane River        Swimming
# 5905           Hoogly River                          Ghat        Standing
#
#                                                   name sex_ age  \
# 0                                          Julie Wolfe    F  57
# 6                               Jose Ernesto da Silva     M  18
# 8                                            Cody High    M  15
# 10                                                male    M  32
# 13                                        Max Berryman    M  21
# ...                                                ...  ...  ..
# 5528  John Hendrick Adrian Chandler, a prisoner of war    M  29
# 5631                                    Horace Hewison    M  19
# 5667                                  Christopher Wang    M  21
# 5797                                      Alexey Drury    M  12
# 5905                                              male    M  35
#
#                 time                                      species_  \
# 0              18h00                                   White shark
# 6     Late afternoon                                   Tiger shark
# 8              17h00                                Bull shark, 6'
# 10           Morning                               Grey reef shark
# 13             08h15                              Invalid incident
# ...              ...                                           ...
# 5528           14h15                                   White shark
# 5631         Morning                              10' to 12' shark
# 5667           Night                                     12' shark
# 5797       Afternoon                                    Bull shark
# 5905    Before 10h30  Identified as C. gangeticus by Dr. J. Fayrer
#
#                                                    href     siglo
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  sigloXXI
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...  sigloXXI
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...  sigloXXI
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...  sigloXXI
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...  sigloXXI
# ...                                                 ...       ...
# 5528  http://sharkattackfile.net/spreadsheets/pdf_di...   sigloXX
# 5631  http://sharkattackfile.net/spreadsheets/pdf_di...   sigloXX
# 5667  http://sharkattackfile.net/spreadsheets/pdf_di...   sigloXX
# 5797  http://sharkattackfile.net/spreadsheets/pdf_di...   sigloXX
# 5905  http://sharkattackfile.net/spreadsheets/pdf_di...   sigloXX
#
# [1502 rows x 16 columns]

# %%
# Ejercicio 11:
# Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.
tiburones.to_csv("./ficheros_pandas/tiburones1.csv")
