# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skew
import scipy.stats as st
import seaborn as sns

# %% [markdown]
# ANÁLISIS FORMAL DE NUESTRO DATASET, UNIVERSIDADES EN UK
#
# En UK conviven 131 Universidades.

# %%
df = pd.read_csv("./Estadística/uk_universities.csv")

# %%
# hacemos un analisis de base, con nuestros metodos favoritos

df.shape
# Out:
# (131, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 21 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   University_name                                131 non-null    object
#  1   Region                                         131 non-null    object
#  2   Founded_year                                   131 non-null    int64
#  3   Motto                                          114 non-null    object
#  4   UK_rank                                        131 non-null    int64
#  5   World_rank                                     131 non-null    int64
#  6   CWUR_score                                     84 non-null     float64
#  7   Minimum_IELTS_score                            131 non-null    float64
#  8   UG_average_fees_(in_pounds)                    131 non-null    int64
# ...

# %%
df.describe(include = "all")
# Out:
#                 University_name  Region  Founded_year  \
# count                       131     131    131.000000
# unique                      131      12           NaN
# top     University of Cambridge  London           NaN
# freq                          1      22           NaN
# mean                        NaN     NaN   1925.221374
# std                         NaN     NaN    139.040187
# min                         NaN     NaN   1096.000000
# 25%                         NaN     NaN   1896.000000
# 50%                         NaN     NaN   1966.000000
# 75%                         NaN     NaN   1992.000000
# max                         NaN     NaN   2013.000000
#
#                                Motto     UK_rank  World_rank  CWUR_score  \
# count                            114  131.000000   131.00000   84.000000
# unique                           113         NaN         NaN         NaN
# top     To know the causes of things         NaN         NaN         NaN
# ...

# %%
df.sample(5)
# Out:
#                           University_name              Region  Founded_year  \
# 18   Royal Holloway, University of London  South East England          1849
# 19              University of Southampton  South East England          1952
# 110                 University of Salford  North West England          1967
# 74       University of Central Lancashire  North West England          1992
# 96          Glasgow Caledonian University            Scotland          1993
#
#                               Motto  UK_rank  World_rank  CWUR_score  \
# 18       To be, rather than to seem       19         129        73.8
# 19   The Heights Yield to Endeavour       20         110        80.9
# 110       Let us seek higher things      111         680        67.7
# 74        From the Earth to the Sun       75         804        68.2
# 96              For the Common Weal       96        1284        67.2
#
#      Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# ...

# %%
# tenemos un df con los registros que son nulos en nuestra columna. NO NOS SIRVE, pero lo guardamos
df_nulos = df[ df["CWUR_score"].isna()]
df_nulos

# %%
# Borramos todos los registros del df que sean nulos en nuestra columna de score.
df_sin_nulos = df[df["CWUR_score"].notnull()]
df_sin_nulos.shape
# Out:
# (84, 21)

# %%
# La relación entre el ranking mundial y la puntuación mundial 

# haríamos una matriz correlacionada de las dos variables
# Nos da una correlación negativa, lo cual tiene sentido, pues a mayor puntuacion "menor" número en el ranking (una posición más alta)


matriz_corr = np.corrcoef(df_sin_nulos["World_rank"],df_sin_nulos["CWUR_score"])
matriz_corr
# Out:
# array([[ 1.        , -0.51235593],
#        [-0.51235593,  1.        ]])

# %%
# Probamos la correlación con el ránking de UK y nos devuelve una mayor correlación negativa. 

matriz_corr2 = np.corrcoef(df_sin_nulos["UK_rank"],df_sin_nulos["CWUR_score"])
matriz_corr2
# Out:
# array([[ 1.        , -0.74996008],
#        [-0.74996008,  1.        ]])

# %%
df_sin_nulos.head()
# Out:
#             University_name              Region  Founded_year  \
# 0   University of Cambridge     East of England          1209
# 1      University of Oxford  South East England          1096
# 2  University of St Andrews            Scotland          1413
# 3   Imperial College London              London          1907
# 4   Loughborough University       East Midlands          1966
#
#                                                Motto  UK_rank  World_rank  \
# 0               From here, light and sacred draughts        1           4
# 1                               The Lord is my light        2           2
# 2                                      Ever to excel        3          86
# 3  Knowledge is the adornment and safeguard of th...        4           8
# 4                   With Truth, Knowledge and Labour        5         404
#
#    CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0        94.1                  6.5                        21750
# ...

# %%
rank_uk = df_sin_nulos[["UK_rank","CWUR_score"]]
rank_uk
# Out:
#      UK_rank  CWUR_score
# 0          1        94.1
# 1          2        93.3
# 2          3        75.8
# 3          4        86.6
# 4          5        72.8
# ..       ...         ...
# 118      119        66.9
# 119      120        68.1
# 121      122        71.1
# 122      123        66.1
# 123      124        66.0
#
# [84 rows x 2 columns]
