# %%
import pandas as pd

# %%
# 1 Cargar dataset (OJO con el encoding)

tiburones = pd.read_csv("./ficheros_pandas/attacks.csv")

tiburones
# Out:
# pandas.core.frame.DataFrame

# %%
# 2 Exploración básica del DataFrame:
# ¿Cuántas filas y columnas tiene el DataFrame?
tiburones.shape
# Out:
# (6114, 22)

# %%
# Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.
tiburones.head()
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    2018.06.25         6303.0         NaN          NaN
# 1    2018.06.18         6302.0         NaN          NaN
# 2    2018.06.09         6301.0         NaN          NaN
# 3    2018.06.08         6300.0         NaN          NaN
# 4    2018.06.04         6299.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
tiburones.tail(5)

# %%
# Mostrad 2 filas al azar del DataFrame.
tiburones.sample(2)
# Out:
#       Unnamed: 0 Case Number    Year        Type  Country       Area  \
# 157          157  2017.04.13  2017.0  Unprovoked      USA    Florida
# 3434        3444  1969.00.00  1969.0    Provoked  BAHAMAS  Eleuthera
#
#                                     Location      Activity  \
# 157   Hanna Park, Jacksonville, Duval County       Surfing
# 3434                                     NaN  Sight-seeing
#
#                                       Name Sex   ...   Species   \
# 157                         Keeanan Perry     M  ...        NaN
# 3434  14' boat, occupant: Jonathan Leodorn  NaN  ...  10' shark
#
#      Investigator or Source                     pdf  \
# 157     News4Jax, 4/14/2017    2017.04.13-Perry.pdf
# 3434    M. Vorenberg, p.154  1969.00.00-Leodorn.pdf
#
#                                            href formula  \
# 157   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3434  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 157   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.04.13
# 3434  http://sharkattackfile.net/spreadsheets/pdf_di...    1969.00.00
#
#      Case Number.2 original order Unnamed: 22  Unnamed: 23
# 157     2017.04.13         6146.0         NaN          NaN
# 3434    1969.00.00         2859.0         NaN          NaN
#
# [2 rows x 22 columns]

# %%
# ¿Cuál es el nombre de las columnas del DataFrame?
tiburones.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
tiburones.dtypes
# Out:
# Unnamed: 0                  int64
# Case Number                object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
# ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.
tiburones.describe()
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %%
tiburones.shape[0]
# Out:
# 6114

# %%
valores_nulos.index
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
valores_nulos
# Out:
# Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64

# %%
valores_nulos[0]
# Out:
# 0

# %%
indices[0]
# Out:
# 'Unnamed: 0'

# %%
indices = valores_nulos.index

# %%
for i in indices:
    print(i)

# %%
indices = valores_nulos.index
for i, j in valores_nulos:

# %%
# ¿Cuál es el porcentaje de valores nulos en cada columna?
valores_nulos = tiburones.isna().sum()



for i in valores_nulos:
    
    porcentaje = i * 100 / tiburones.shape[0]
    
    print(f"el porcentaje de valores nulos de {valores_nulos} es de {porcentaje}")
# Out:
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.016355904481517827
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0654236179260713
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.6542361792607131
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 6.673209028459274
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 7.9816813869807
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 8.357867190055611
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 3.271180896303566
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 8.995747464834805
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 43.60484134772653
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 52.01177625122669
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 44.24272162250573
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.2616944717042852
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.016355904481517827
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 0.0
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 99.98364409551849
# el porcentaje de valores nulos de Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64 es de 99.96728819103697

# %%
type(tiburones)
# Out:
# pandas.core.frame.DataFrame

# %%
for i in tiburones:
    print(i)
# Out:
# Unnamed: 0
# Case Number
# Year
# Type
# Country
# Area
# Location
# Activity
# Name
# Sex
# Age
# Time
# Species
# Investigator or Source
# pdf
# href formula
# href
# Case Number.1
# Case Number.2
# original order
# Unnamed: 22
# Unnamed: 23

# %%
# Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.
#tiburones["Unnamed: 0","Year","original order"].unique()

var1_dict = dict(tiburones["Unnamed: 0"].value_counts())
var2_dict = dict(tiburones["Year"].value_counts())
var3_dict = dict(tiburones["original order"].value_counts())

# %%
var3_dict

# %%
# Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.
columnas_nuevas = {col: col.lower() for col in tiburones.columns}
tiburones.rename(columns = columnas_nuevas, inplace = True)

tiburones

# %%
columnas = tiburones.columns

# %%
for i in columnas:
    list_vacia = []
    nuevo_nombre = i.replace(" ","_")
    list_vacia.append(nuevo_nombre)
    print(list_vacia)
# Out:
# ['unnamed:_0']
# ['case_number']
# ['year']
# ['type']
# ['country']
# ['area']
# ['location']
# ['activity']
# ['name']
# ['sex_']
# ['age']
# ['time']
# ['species_']
# ['investigator_or_source']
# ['pdf']
# ['href_formula']
# ['href']
# ['case_number.1']
# ['case_number.2']
# ['original_order']
# ['unnamed:_22']
# ['unnamed:_23']

# %%
columnas
# Out:
# Index(['unnamed: 0', 'case number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex ', 'age', 'time', 'species ',
#        'investigator or source', 'pdf', 'href formula', 'href',
#        'case number.1', 'case number.2', 'original order', 'unnamed: 22',
#        'unnamed: 23'],
#       dtype='object')

# %%
# Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

# %%
# Guarda el csv que no tiene esas columnas para seguir usándolo mañana.
