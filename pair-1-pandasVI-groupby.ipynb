# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./ficheros_pandas/info_tiburones.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6286 entries, 0 to 6285
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             6285 non-null   object
#  1   Fatal (Y/N)             5751 non-null   object
#  2   Injury                  6258 non-null   object
#  3   Date                    6286 non-null   object
#  4   year                    6284 non-null   float64
#  5   type                    6280 non-null   object
#  6   country                 6234 non-null   object
#  7   area                    5830 non-null   object
#  8   location                5745 non-null   object
#  9   activity                5742 non-null   object
#  10  name                    6075 non-null   object
#  11  sex_                    5720 non-null   object
#  12  age                     3464 non-null   object
#  13  time                    2944 non-null   object
# ...

# %%
# Ejercicio 1. Cuántos ataques hubo por país? Devuelve un DataFrame. (ordénalos de mayor a menor. Usa .sort_values())

ataques = pd.DataFrame(df.groupby("country")["country"].count().sort_values(ascending=False))
ataques.head()
# Out:
#                   country
# country
# USA                  2222
# AUSTRALIA            1335
# SOUTH AFRICA          577
# PAPUA NEW GUINEA      134
# NEW ZEALAND           127

# %%
# Ejercicio 2. ¿Cuántos ataques ha habido por año? Devuelve un DataFrame. De nuevo ordena los resultados de mayor a menor.

ataques_ano = pd.DataFrame(df.groupby("year")["year"].count().sort_values(ascending=False))
ataques_ano.head()
# Out:
#         year
# year
# 2015.0   143
# 2017.0   136
# 2016.0   130
# 2011.0   128
# 2014.0   126

# %%
# Ejercicio 3. ¿Cuántos ataques hubo por año y sexo? Devolved un DataFrame solo del año 2000 en adelante.

ataque_2000 = df[df["year"] >= 2000]
ataque_2000.head()
# Out:
#   case_number Fatal (Y/N)                                             Injury  \
# 0  2018.06.25           N  No injury to occupant, outrigger canoe and pad...
# 1  2018.06.18           N                         Minor injury to left thigh
# 2  2018.06.09           N       Injury to left lower leg from surfboard skeg
# 3  2018.06.08           N                          Minor injury to lower leg
# 4  2018.06.04           N  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#           Date    year        type    country             area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity  ...  age           time  \
# ...

# %%
ataques_ano_sex = ataque_2000.groupby(["year","sex_"])['type'].count().reset_index()
df_ataques_ano_sex = pd.DataFrame(ataques_ano_sex)
df_ataques_ano_sex.head()
# Out:
#      year sex_  type
# 0  2000.0    F    12
# 1  2000.0    M    74
# 2  2001.0    F    13
# 3  2001.0    M    71
# 4  2002.0    F     9

# %%
# Ejercicio 4. Primero extraed solo las filas que correspondan a USA, AUSTRALIA y SOUTH AFRICA. 
# ¿Cuántos de los ataques fueron letales por sexo? Devuelve un DataFrame.

# %%
ataques_uas = df[(df["country"] == "USA") | (df["country"] == "SOUTH AFRICA") | (df["country"] == "AUSTRALIA")]
ataques_uas.head()
# Out:
#     case_number Fatal (Y/N)  \
# 0    2018.06.25           N
# 1    2018.06.18           N
# 2    2018.06.09           N
# 3    2018.06.08           N
# 5  2018.06.03.b           N
#
#                                               Injury         Date    year  \
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018  2018.0
# 1                         Minor injury to left thigh  18-Jun-2018  2018.0
# 2       Injury to left lower leg from surfboard skeg  09-Jun-2018  2018.0
# 3                          Minor injury to lower leg  08-Jun-2018  2018.0
# 5                            No injury, board bitten  03-Jun-2018  2018.0
#
#          type    country             area                        location  \
# 0     Boating        USA       California     Oceanside, San Diego County
# 1  Unprovoked        USA          Georgia  St. Simon Island, Glynn County
# 2     Invalid        USA           Hawaii                    Habush, Oahu
# ...

# %%
ataques_uas_groupby = pd.DataFrame(ataques_uas.groupby(["sex_", "Fatal (Y/N)", "country"])["case_number"].count()).reset_index()

letales = ataques_uas_groupby[ataques_uas_groupby["Fatal (Y/N)"] == "Y"]
letales
# Out:
#    sex_ Fatal (Y/N)       country  case_number
# 6     F           Y     AUSTRALIA           17
# 7     F           Y  SOUTH AFRICA            5
# 8     F           Y           USA           13
# 16    M           Y     AUSTRALIA          264
# 17    M           Y  SOUTH AFRICA          100
# 18    M           Y           USA          169

# %%
# Ejercicio 5. Usando el DataFrame creado en el ejercicio anterior. ¿En qué país hubo más ataques?

letales.max()
# Out:
# sex_             M
# Fatal (Y/N)      Y
# country        USA
# case_number    264
# dtype: object

# %%
# Ejercicio 6. ¿Qué y cuántos tipos de ataques hubo por país?

# %%
estudio = pd.DataFrame(ataques_uas.groupby(["country","type"])["case_number"].count())
estudio
# Out:
#                            case_number
# country      type
# AUSTRALIA    Boat                   39
#              Boating                83
#              Invalid               118
#              Provoked              136
#              Questionable            2
#              Sea Disaster           24
#              Unprovoked            932
# SOUTH AFRICA Boat                   37
#              Boating                15
#              Invalid                64
#              Provoked               54
#              Sea Disaster            5
#              Unprovoked            402
# USA          Boat                   23
#              Boating                52
#              Invalid               192
#              Provoked              205
#              Sea Disaster           32
#              Unprovoked           1717
