# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
info_tiburones = pd.read_csv("./ficheros_pandas/info_tiburones.csv")

# %%
info_tiburones.sample(5)
# Out:
#      case_number Fatal (Y/N)  \
# 3771  1962.11.11           N
# 5205  1922.09.29           Y
# 1640  2004.08.06           N
# 4105  1959.01.15           N
# 2747  1988.01.14           N
#
#                                                  Injury         Date    year  \
# 3771           Arm, hand, buttock, leg and thigh bitten  11-Nov-1962  1962.0
# 5205                                              FATAL  29-Sep-1922  1922.0
# 1640  Back, buttocks, left hand & left side of face ...  06-Aug-2004  2004.0
# 4105                      Thigh & both wrists lacerated  15-Jan-1959  1959.0
# 2747    Hand bitten by captured shark PROVOKED INCIDENT  14-Jan-1988  1988.0
#
#             type       country                   area  \
# 3771  Unprovoked           USA             California
# 5205  Unprovoked      BARBADOS                   Lucy
# 1640  Unprovoked           USA                Florida
# 4105  Unprovoked  SOUTH AFRICA  Western Cape Province
# ...

# %%
# Ejercicio 1. Usando la librería seaborn, crea una gráfica de barras que muestre el número de personas que han hecho cada actividad en cada año. Hacedlo solo desde el 2015. 
# Os podrá salir una gráfica un poco fea, no os preocupeis, es lo que esperamos

# %%
fig = sns.countplot(x='variable_x', data = dataset)

# %%
dff = info_tiburones[info_tiburones["year"] >= 2015]
dff
# Out:
#     case_number Fatal (Y/N)  \
# 0    2018.06.25           N
# 1    2018.06.18           N
# 2    2018.06.09           N
# 3    2018.06.08           N
# 4    2018.06.04           N
# ..          ...         ...
# 458  2015.01.16           N
# 459  2015.01.08         NaN
# 460  2015.01.06           N
# 461  2015.01.03           N
# 462  2015.01.01           N
#
#                                                 Injury         Date    year  \
# 0    No injury to occupant, outrigger canoe and pad...  25-Jun-2018  2018.0
# 1                           Minor injury to left thigh  18-Jun-2018  2018.0
# 2         Injury to left lower leg from surfboard skeg  09-Jun-2018  2018.0
# 3                            Minor injury to lower leg  08-Jun-2018  2018.0
# 4    Lacerations to leg & hand shark PROVOKED INCIDENT  04-Jun-2018  2018.0
# ..                                                 ...          ...     ...
# 458                             Bitten on hand & wrist  16-Jan-2015  2015.0
# ...

# %%
df1 = dff.groupby(["year", "activity"])
df1.sample()
# Out:
#       case_number Fatal (Y/N)  \
# 417    2015.06.05           N
# 401  2015.06.27.a           N
# 351  2015.10.05.b           N
# 396    2015.07.02           N
# 406    2015.06.25           N
# ..            ...         ...
# 20   2018.04.25.b           N
# 43     2018.02.14           N
# 36     2018.03.14           N
# 42     2018.02.15           N
# 32     2018.04.09           N
#
#                                                 Injury         Date    year  \
# 417                           Puncture wound to finger  05-Jun-2015  2015.0
# 401  Right leg severed, multiple lacerations to lef...  27-Jun-2015  2015.0
# 351                             2 lacerations to ankle  05-Oct-2015  2015.0
# 396                 Significant injuries to lower legs  02-Jul-2015  2015.0
# 406                       Multiple lacerations to back  25-Jun-2015  2015.0
# ..                                                 ...          ...     ...
# ...

# %%
df2 = pd.DataFrame(df1)
df2
# Out:
#                                           0  \
# 0    (2015.0, Attempting to rescue a shark)
# 1                   (2015.0, Body Boarding)
# 2                   (2015.0, Body boarding)
# 3                  (2015.0, Body boarding )
# 4                   (2015.0, Body surfing?)
# ..                                      ...
# 127                       (2018.0, Surfing)
# 128                      (2018.0, Swimming)
# 129                        (2018.0, Wading)
# 130                       (2018.0, Walking)
# 131                   (2018.0, Windsurfing)
#
#                                                      1
# 0        case_number Fatal (Y/N)                   ...
# 1          case_number Fatal (Y/N)  \
# 401  2015.06....
# 2          case_number Fatal (Y/N)  \
# 339  2015.10....
# 3        case_number Fatal (Y/N)                   ...
# 4        case_number Fatal (Y/N)                   ...
# ..                                                 ...
# ...

# %%
fig = sns.countplot(x='year', data = df2, hue = 'activity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4t/jwz4fg1j3ps9fv1187b_jzr40000gn/T/ipykernel_1803/880344601.py in <module>
# ----> 1 fig = sns.countplot(x='year', data = df2, hue = 'activity')
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
# ...

# %%
# Ejercicio 2 Usando la librería seaborn, crea una gráfica de barras que muestre el número de ataques que han ocurrido cada año en función del sexo. Hacedlo solo desde el 2015.

# %%
df4 = info_tiburones[(info_tiburones["year"] >= 2015) & ((info_tiburones["sex_"] == "M") | (info_tiburones["sex_"] == "F"))]
df4
# Out:
#     case_number Fatal (Y/N)  \
# 0    2018.06.25           N
# 1    2018.06.18           N
# 2    2018.06.09           N
# 3    2018.06.08           N
# 4    2018.06.04           N
# ..          ...         ...
# 458  2015.01.16           N
# 459  2015.01.08         NaN
# 460  2015.01.06           N
# 461  2015.01.03           N
# 462  2015.01.01           N
#
#                                                 Injury         Date    year  \
# 0    No injury to occupant, outrigger canoe and pad...  25-Jun-2018  2018.0
# 1                           Minor injury to left thigh  18-Jun-2018  2018.0
# 2         Injury to left lower leg from surfboard skeg  09-Jun-2018  2018.0
# 3                            Minor injury to lower leg  08-Jun-2018  2018.0
# 4    Lacerations to leg & hand shark PROVOKED INCIDENT  04-Jun-2018  2018.0
# ..                                                 ...          ...     ...
# 458                             Bitten on hand & wrist  16-Jan-2015  2015.0
# ...

# %%
df4["year"].value_counts()
# Out:
# 2015.0    141
# 2017.0    131
# 2016.0    126
# 2018.0     52
# Name: year, dtype: int64

# %%
plt.figure(figsize =(8,4))
fig = sns.countplot(x='year', data = df4, hue = 'sex_')
fig.set(xlabel='Años', ylabel= 'Número de ataques' )
fig.set_title('Número de ataques en función del sexo')
plt.show()

# %%
# Ejercicio 3 ¿Cuántos ataques hubo por año? Seleccionad solo desde el año 1500.

# %%
df5 = info_tiburones[info_tiburones["year"] >= 1500 ]
df5
# Out:
#        case_number Fatal (Y/N)  \
# 0       2018.06.25           N
# 1       2018.06.18           N
# 2       2018.06.09           N
# 3       2018.06.08           N
# 4       2018.06.04           N
# ...            ...         ...
# 6153    1595.00.00     UNKNOWN
# 6154  1580.01.10.R           Y
# 6155    1555.00.00     UNKNOWN
# 6156    1554.00.00     UNKNOWN
# 6157    1543.00.00           Y
#
#                                                  Injury  \
# 0     No injury to occupant, outrigger canoe and pad...
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 3                             Minor injury to lower leg
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT
# ...                                                 ...
# 6153  Leg severed mid-thigh, hand severed, arm above...
# 6154                  FATAL. "Shark tore him to pieces.
# 6155                                                NaN
# ...

# %%
plt.figure(figsize =(100,8))
fig = sns.countplot(x='year', data = df5)
fig.set(xlabel='Años', ylabel= 'Número de ataques' )
fig.set_title('Número de ataques a lo largo del a historia')
plt.show()

# %%
# Ejercicio 3 ¿Cuántos ataques hubo por año? Seleccionad solo desde el año 1500.
