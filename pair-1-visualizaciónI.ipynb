# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# tenemos que trabajar con el archivo generado el día de pandas III , es decir tiburones

tiburones = pd.read_csv("./ficheros_pandas/tiburones.csv")

# %%
tiburones.head(5)
# Out:
#    Unnamed: 0  unnamed:_0 case_number    year        type    country  \
# 0           0           0  2018.06.25  2018.0     Boating        USA
# 1           1           1  2018.06.18  2018.0  Unprovoked        USA
# 2           2           2  2018.06.09  2018.0     Invalid        USA
# 3           3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA
# 4           4           4  2018.06.04  2018.0    Provoked     MEXICO
#
#               area                        location     activity  \
# 0       California     Oceanside, San Diego County     Paddling
# 1          Georgia  St. Simon Island, Glynn County     Standing
# 2           Hawaii                    Habush, Oahu      Surfing
# 3  New South Wales              Arrawarra Headland      Surfing
# 4           Colima                        La Ticla  Free diving
#
#               name sex_  age           time         species_  \
# 0      Julie Wolfe    F   57          18h00      White shark
# ...

# %%
# Ejercicio 1

frecuencia_sex = tiburones["sex_"].value_counts()
plt.figure()
x = frecuencia_sex.index
y = frecuencia_sex.values
plt.bar(x,y)
plt.show()

# %%
# Ejercicio 2. 
# ¿Cuál es el porcentaje de nulos por columna? Usa un pie chart donde incluyáis el porcentaje de cada variable en el interior del quesito. 
# Para eso tendréis que usar el parámetro autopct,

# %%
nulos = tiburones.isnull().sum()
array = []

for i in nulos:
    i2 = (i / tiburones.shape[0] * 100)
    array.append(i2)

# %%
plt.figure
plt.pie(array, labels = nulos.index)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Ejercicio 3 
# ¿Cuál es el número total de valores únicos de cada una de las columnas categóricas del DataFrame?

# %%
df = tiburones.describe(include = "object")
df
# Out:
#        case_number        type country     area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 location activity  name  sex_   age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              time     species_  \
# count        2934         3409
# unique        366         1529
# top     Afternoon  White shark
# freq          183          161
#
#                                                      href
# count                                                6114
# unique                                               6099
# ...

# %%
unicos = df.iloc[1]

# %%
plt.figure()
x = unicos.index
y = unicos.values
plt.barh(x,y)
plt.show()

# %%
# Ejercicio 4
# Filtrad los datos para quedarnos solo con los datos de USA
# ¿Cuántos ataques de tiburones hubo en USA a lo largo del tiempo? Muestra solo los que hayan ocurrido del 2000 en adelante
# En función del tipo, ¿cuántos ataques de tiburones de cada tipo hubo en USA? Muestra los resultados en un gráfico de línea

# %%
ataques_usa = tiburones[(tiburones["country"] == "USA")]
ataques_usa.head(5)
# Out:
#    Unnamed: 0  unnamed:_0   case_number    year        type country  \
# 0           0           0    2018.06.25  2018.0     Boating     USA
# 1           1           1    2018.06.18  2018.0  Unprovoked     USA
# 2           2           2    2018.06.09  2018.0     Invalid     USA
# 7           7           7    2018.05.27  2018.0  Unprovoked     USA
# 8           8           8  2018.05.26.b  2018.0  Unprovoked     USA
#
#          area                                           location  activity  \
# 0  California                        Oceanside, San Diego County  Paddling
# 1     Georgia                     St. Simon Island, Glynn County  Standing
# 2      Hawaii                                       Habush, Oahu   Surfing
# 7     Florida  Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing
# 8     Florida                       Cocoa Beach, Brevard  County   Walking
#
#               name sex_ age           time         species_  \
# ...

# %%
ataques_usa_recientes = tiburones[(tiburones["year"] > 2000) & (tiburones["country"] == "USA")]
ataques_usa_recientes.head(5)
# Out:
#    Unnamed: 0  unnamed:_0   case_number    year        type country  \
# 0           0           0    2018.06.25  2018.0     Boating     USA
# 1           1           1    2018.06.18  2018.0  Unprovoked     USA
# 2           2           2    2018.06.09  2018.0     Invalid     USA
# 7           7           7    2018.05.27  2018.0  Unprovoked     USA
# 8           8           8  2018.05.26.b  2018.0  Unprovoked     USA
#
#          area                                           location  activity  \
# 0  California                        Oceanside, San Diego County  Paddling
# 1     Georgia                     St. Simon Island, Glynn County  Standing
# 2      Hawaii                                       Habush, Oahu   Surfing
# 7     Florida  Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing
# 8     Florida                       Cocoa Beach, Brevard  County   Walking
#
#               name sex_ age           time         species_  \
# ...

# %%
tipo = ataques_usa_recientes["type"].value_counts()
tipo
# Out:
# Unprovoked      797
# Invalid          65
# Provoked         60
# Boating          32
# Boat              3
# Sea Disaster      2
# Name: type, dtype: int64

# %%
plt.figure
x = tipo.index
y = tipo.values
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Ejercicio 5 
# Filtrad los datos para Spain
# Cuántos ataques de tiburones hubo en España a lo largo del tiempo? Muestra solo los que hayan ocurrido del 2000 en adelante
# En función del tipo, ¿cuántos ataques de cada tipo de tiburones hubo en España? Muestra los resultados en un gráfico de línea #

# %%
ataques_spain_recientes = tiburones[(tiburones["year"] > 2000) & (tiburones["country"] == "SPAIN")]
ataques_spain_recientes.head(5)
# Out:
#      Unnamed: 0  unnamed:_0   case_number    year        type country  \
# 82           82          82  2017.09.16.b  2017.0  Unprovoked   SPAIN
# 98           98          98  2017.08.26.b  2017.0     Invalid   SPAIN
# 113         113         113  2017.07.23.a  2017.0  Unprovoked   SPAIN
# 130         130         130    2017.06.17  2017.0  Unprovoked   SPAIN
# 233         233         234    2016.07.29  2016.0  Unprovoked   SPAIN
#
#                   area                        location      activity    name  \
# 82      Canary Islands                   Gran Canaria   Body surfing    male
# 98           Castellón                 Grao de Moncofa      Swimming  female
# 113            Majorca  Estanys Beach, Colonia de Sant      Swimming  female
# 130       Ibiza Island                Playa den Bossa      Swimming    male
# 233  Alicante Province                Arenales del Sol      Swimming    male
#
#     sex_  age       time                        species_  \
# ...

# %%
tipo2 = ataques_spain_recientes["type"].value_counts()
tipo2
# Out:
# Unprovoked    9
# Invalid       5
# Provoked      2
# Name: type, dtype: int64

# %%
plt.figure
x1 = tipo2.index
y1 = tipo2.values
plt.plot(x1,y1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
